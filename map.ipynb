# %%
import geopandas as gpd
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import osmnx as ox

# %%
path = "municipalities/oria_dhmwn_kallikraths.shp"
gdf = gpd.read_file(path, encoding = "iso 8859-7")
# Out:
# ---------------------------------------------------------------------------
# CPLE_OpenFailedError                      Traceback (most recent call last)
# fiona/_shim.pyx in fiona._shim.gdal_open_vector()
#
# fiona/_err.pyx in fiona._err.exc_wrap_pointer()
#
# CPLE_OpenFailedError: municipalities/oria_dhmwn_kallikraths.shp: No such file or directory
#
# During handling of the above exception, another exception occurred:
#
# DriverError                               Traceback (most recent call last)
# <ipython-input-2-21f5b4c5598c> in <module>
#       1 path = "municipalities/oria_dhmwn_kallikraths.shp"
# ----> 2 gdf = gpd.read_file(path, encoding = "iso 8859-7")
#
# ~/miniconda3/envs/ox/lib/python3.8/site-packages/geopandas/io/file.py in read_file(filename, bbox, mask, rows, **kwargs)
#      87
#      88     with fiona_env():
# ---> 89         with reader(path_or_bytes, **kwargs) as features:
#      90
# ...

# %%
gdf.head()

# %%
selection = gdf.loc[gdf["NAME"]=="Παύλου Μελά"]

# %%
selection.plot()

# %%
graph = ox.pois_from_polygon(selection_wgs.geometry.values[0])

# %%
nodes, edges = ox.graph_to_gdfs(graph)

# %%
selection_wgs = selection.to_crs({'init': 'epsg:4326'})

# %%
leisure = ox.footprints_from_polygon(selection_wgs.geometry.values[0], footprint_type="leisure")

# %%
parks = leisure[leisure["leisure"].isin(["park", "playground"])]

# %%
fig, ax = plt.subplots(figsize=(12,8))

# Plot the footprint
selection_wgs.plot(ax=ax, facecolor='black', label="sadas")

# Plot street edges
#graph.plot(ax=ax, linewidth=1, edgecolor='#BC8F8F', label="sdasd")

# Plot buildings
parks.plot(ax=ax, facecolor='green', alpha=0.7, label="sadas")
plt.legend()
# Plot restaurants
#restaurants.plot(ax=ax, color='green', alpha=0.7, markersize=10)
plt.tight_layout()
plt.show()
# Out:
# No handles with labels found to put in legend.

# %%
graph
# Out:
#                  osmid                                           geometry  \
# 1100321490  1100321490                          POINT (22.95844 40.65693)
# 1196599558  1196599558                          POINT (22.92855 40.67144)
# 1488961207  1488961207                          POINT (22.93694 40.66508)
# 1488961224  1488961224                          POINT (22.93609 40.66491)
# 1488961225  1488961225                          POINT (22.93609 40.66483)
# ...                ...                                                ...
# 613469049    613469049  POLYGON ((22.94668 40.66640, 22.94686 40.66648...
# 636327462    636327462  POLYGON ((22.93834 40.67104, 22.93813 40.67107...
# 770541312    770541312  POLYGON ((22.94461 40.68186, 22.94491 40.68171...
# 770541316    770541316  POLYGON ((22.94454 40.68246, 22.94488 40.68244...
# 770541317    770541317  POLYGON ((22.94454 40.68201, 22.94463 40.68196...
#
#                  amenity denomination                              name  \
# ...
